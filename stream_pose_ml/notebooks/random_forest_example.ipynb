# %% [markdown]
# # Model Experiments - Random Forest

# %% [markdown]
# First, load in dependencies, as well as the ModelBuilder which is meant for rapidly iterating on various options for our datasets and models.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from stream_pose_ml.stream_pose_ml.learning import model_builder as mb
from scipy.stats import randint

# Mapping string categories to numerical
value_map = {
    "weight_transfer_type": {
        "Failure Weight Transfer": 0,
        "Successful Weight Transfer": 1,
    },
    "step_type": {
        "Left Step": 0,
        "Right Step": 1,
    },
}
# Columns we know we'll always want to drop
drop_list = ["video_id"]
# Only keep these columns (including target)
column_whitelist = []

# %% [markdown]
# There are a variety of datasets to choose from and more can be generated. Here is a list:

# %%
# this one is the original "avg dataset used"
# data_file = "./data/annotated_videos/dataset_1678732901064497000.csv"

# this one includes more pooled stats (max)
# data_file = "./data/annotated_videos/dataset_1679002854718304000.csv"

# this one is 45 frame window pooled
# data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

# this one is 25 frame window pooled
# data_file = "./data/annotated_videos/dataset_1679016147487099000.csv"

# this one is a flat column representation frame by frame angles of a labeled 10 frame window
# data_file = "./data/annotated_videos/dataset_1679087888313443000.csv"

# this one is a flat column representation frame by frame angles of a labeled 25 frame window
# data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

# %% [markdown]
# # Model / Dataset comparisons

# %% [markdown]
# We're looking predict the target variable "weight_transfer_type". Our dataset is pretty imbalanced, with most examples being a "successful weight transfer".

# %% [markdown]
# ## Dataset 1
#
# ### Flat column representation, frame by frame angles of distinct labeled frames over a 25 frame window
#
# The following tests will use the 25 frame window flattened into a single row. We'll train a Random Forest Classifier using consistent training parameters and a consistent train / test split.
#
# Preliminary results show decent accuract, however AUC was fairly low (in the 60s generally) so the hypothesis is that the dataset is unbalanced. So here I'm going to try and few different strategies for rebalancing the dataset and comparing them
#
# Random Forest Spec:
# * Num estimators 600
# * Max Depth 9
# * Max Leaf Notes: 63
#
# These features are compared to a well-performing AutoML model - SparseNormalizer, XGBoostClassifier

# %% [markdown]
# ### Test 1
# First, let's upsample the minority class by just randomly oversampling. Then train the data on a random forest classifier:

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

# reload model builder class (iterating on it a lot)
importlib.reload(mb)
model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

# mb.run_pca(num_components=5)
model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=123,
)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    965
# 0    965
# Name: weight_transfer_type, dtype: int64
# Top 25 features
# {'angles_max.frame-22-line_1_2__line_2_3_angle_2d_degrees': '0.4713461159626379%'}
# {'angles_avg.frame-22-line_1_2__line_2_3_angle_2d_degrees': '0.37728530471815935%'}
# {'angles_max.frame-23-line_1_2__line_2_3_angle_2d_degrees': '0.36280239082343807%'}
# {'angles_max.frame-20-line_1_2__line_2_3_angle_2d_degrees': '0.32207034066571427%'}
# {'angles_max.frame-21-line_1_2__line_2_3_angle_2d_degrees': '0.3093722953485288%'}
# {'angles_avg.frame-20-line_1_2__line_2_3_angle_2d_degrees': '0.2722872649138894%'}
# {'angles_avg.frame-22-line_5_6__line_6_7_angle_2d_degrees': '0.26657902693422847%'}
# {'angles_avg.frame-16-line_2_3__line_3_4_angle_2d_degrees': '0.2655737205699982%'}
# {'angles_avg.frame-18-line_1_5__line_25_26_angle_2d_degrees': '0.2624022619905564%'}
# {'angles_max.frame-17-line_1_2__line_2_3_angle_2d_degrees': '0.24623770830271557%'}
# {'angles_max.frame-19-line_1_2__line_2_3_angle_2d_degrees': '0.23651750708904787%'}
# {'angles_max.frame-18-line_1_5__line_5_6_angle_2d_degrees': '0.23455185710198512%'}
# {'angles_max.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.23208409947598554%'}
# {'angles_avg.frame-23-line_1_2__line_2_3_angle_2d_degrees': '0.22807330677102272%'}
# {'angles_avg.frame-16-line_1_2__line_2_3_angle_2d_degrees': '0.2090738721464308%'}
# {'angles_avg.frame-18-line_5_6__line_6_7_angle_2d_degrees': '0.20778100675981492%'}
# {'angles_avg.frame-12-line_5_6__line_6_7_angle_2d_degrees': '0.20733956679383808%'}
# {'angles_avg.frame-16-line_3_4__line_25_26_angle_2d_degrees': '0.20499266533507782%'}
# {'angles_avg.frame-17-line_3_4__line_25_26_angle_2d_degrees': '0.2021448151317349%'}
# {'angles_avg.frame-13-line_1_5__line_5_6_angle_2d_degrees': '0.1970671056474819%'}
# {'angles_avg.frame-18-line_1_2__line_2_3_angle_2d_degrees': '0.19417348648560667%'}
# {'angles_max.frame-16-line_3_4__line_25_26_angle_2d_degrees': '0.19384752811944134%'}
# {'angles_avg.frame-9-line_2_3__line_3_4_angle_2d_degrees': '0.19110815541873183%'}
# {'angles_avg.frame-15-line_3_4__line_25_26_angle_2d_degrees': '0.19034542134665458%'}
# {'angles_avg.frame-22-line_3_4__line_25_26_angle_2d_degrees': '0.1901311930210576%'}
# Mean ROC AUC from cross validation: 0.963
# Min ROC AUC from cross validation: 0.927
# Max ROC AUC from cross validation: 0.987
# Classification Metrics:
# Accuracy: 0.8622
# Precision: 0.8919
# Recall: 0.9545
# F1 Score: 0.9222
# ROC AUC: 0.7829
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.32      0.40        41
#            1       0.89      0.95      0.92       242
#
#     accuracy                           0.86       283
#    macro avg       0.72      0.64      0.66       283
# weighted avg       0.84      0.86      0.85       283

# %% [markdown]
# These results show a fairly low AUC (Area under curve) as well as a relatively low F1 score for the macro avg.

# %% [markdown]
# ### Test 2
#
# Next try SMOTE - synthetically generate new samples based on minority samples.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

# mb.run_pca(num_components=5)
model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=True,
    random_state=123,
)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 0    965
# 1    965
# Name: weight_transfer_type, dtype: int64
# Mean ROC AUC from cross validation: 0.965
# Min ROC AUC from cross validation: 0.940
# Max ROC AUC from cross validation: 0.988
# /Users/nathanielgreen/Dev-Local/stream_pose_ml/stream_pose_ml/stream_pose_ml/learning/model_builder.py:278: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   )
# Classification Metrics:
# Accuracy: 0.8481
# Precision: 0.8902
# Recall: 0.9380
# F1 Score: 0.9135
# ROC AUC: 0.7777
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.32      0.38        41
#            1       0.89      0.94      0.91       242
#
#     accuracy                           0.85       283
#    macro avg       0.68      0.63      0.65       283
# weighted avg       0.83      0.85      0.84       283

# %% [markdown]
# Simlar to results without SMOTE.

# %% [markdown]
# ### Test 3
#
# Downsample the majority class.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

# reload model builder class (iterating on it a lot)
model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

# mb.run_pca(num_components=5)
model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=False,
    downsample_majority=True,
    use_SMOTE=False,
    random_state=123,
)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    167
# 0    167
# Name: weight_transfer_type, dtype: int64
# Top 25 features
# [{'angles_max.frame-22-line_5_6__line_6_7_angle_2d_degrees': '0.4271267361998467%'}, {'angles_max.frame-25-line_5_6__line_6_7_angle_2d_degrees': '0.31050105392229144%'}, {'angles_avg.frame-22-line_5_6__line_6_7_angle_2d_degrees': '0.30280101375554325%'}, {'angles_max.frame-23-line_5_6__line_6_7_angle_2d_degrees': '0.29720671987396824%'}, {'angles_max.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0
frame-20-line_5_6__line_6_7_angle_2d_degrees': '0.31767825256357474%'}
# {'angles_max.frame-15-line_3_4__line_25_26_angle_2d_degrees': '0.3035670400489272%'}
# {'angles_avg.frame-17-line_5_6__line_6_7_angle_2d_degrees': '0.2960009135451769%'}
# {'angles_max.frame-18-line_5_6__line_6_7_angle_2d_degrees': '0.2748754888702538%'}
# {'angles_max.frame-12-line_3_4__line_25_26_angle_2d_degrees': '0.2665621856415629%'}
# {'angles_max.frame-13-line_3_4__line_25_26_angle_2d_degrees': '0.26590278607149076%'}
# {'angles_avg.frame-18-line_3_4__line_25_26_angle_2d_degrees': '0.26528706338776264%'}
# {'angles_avg.frame-12-line_3_4__line_25_26_angle_2d_degrees': '0.2634981229699523%'}
# {'angles_max.frame-15-line_15_17__line_25_26_angle_2d_degrees': '0.2566620063927392%'}
# {'angles_max.frame-19-line_5_6__line_6_7_angle_2d_degrees': '0.2508449560808875%'}
# {'angles_max.frame-14-line_3_4__line_25_26_angle_2d_degrees': '0.2450265682999486%'}
# {'angles_avg.frame-23-line_5_6__line_6_7_angle_2d_degrees': '0.24056783145095215%'}
# {'angles_max.frame-24-line_5_6__line_6_7_angle_2d_degrees': '0.22980389041318028%'}
# {'angles_avg.frame-18-line_15_17__line_25_26_angle_2d_degrees': '0.22722413191132526%'}
# {'angles_max.frame-16-line_5_6__line_6_7_angle_2d_degrees': '0.21409927443885637%'}
# {'angles_avg.frame-16-line_3_4__line_25_26_angle_2d_degrees': '0.2138126692201853%'}
# {'angles_avg.frame-14-line_3_4__line_25_26_angle_2d_degrees': '0.2113104305953066%'}
# Mean ROC AUC from cross validation: 0.964
# Min ROC AUC from cross validation: 0.928
# Max ROC AUC from cross validation: 0.989
# Classification Metrics:
# Accuracy: 0.8551
# Precision: 0.8628
# Recall: 0.9876
# F1 Score: 0.9210
# ROC AUC: 0.7537
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.07      0.13        41
#            1       0.86      0.99      0.92       242
#
#     accuracy                           0.86       283
#    macro avg       0.68      0.53      0.52       283
# weighted avg       0.81      0.86      0.81       283

# %% [markdown]
# These results also look similar.

# %% [markdown]
# ### Test 5
#
# In general each technique gave similar results. I also fixed the train test split for each case. Let's try a few runs of oversampling the minority class (without SMOTE on some different train test splits). I want to try this because the cross validation scores are tending to have very nice ROC AUC scores (in the 90s) and so just want to rule out that the particular split I'm using for the previous scores isn't particularly bad.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

# reload model builder class (iterating on it a lot)
importlib.reload(mb)
model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

# mb.run_pca(num_components=5)
model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=300,
)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    971
# 0    971
# Name: weight_transfer_type, dtype: int64
# Top 25 features
# {'angles_max.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.37405887694934264%'}
# {'angles_avg.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.33791450496789166%'}
# {'angles_avg.frame-21-line_3_4__line_25_26_angle_2d_degrees': '0.29719235395327476%'}
# {'angles_max.frame-12-line_3_4__line_25_26_angle_2d_degrees': '0.2803347654727033%'}
# {'angles_avg.frame-18-line_3_4__line_25_26_angle_2d_degrees': '0.2779264903043805%'}
# {'angles_avg.frame-14-line_3_4__line_25_26_angle_2d_degrees': '0.26367731702542474%'}
# {'angles_avg.frame-19-line_2_3__line_3_4_angle_2d_degrees': '0.24833196951694805%'}
# {'angles_max.frame-17-line_3_4__line_25_26_angle_2d_degrees': '0.23617960888591016%'}
# {'angles_max.frame-2-line_1_5__line_5_6_angle_2d_degrees': '0.2333834496855864%'}
# {'angles_max.frame-11-line_3_4__line_25_26_angle_2d_degrees': '0.23161445330681418%'}
# {'angles_avg.frame-15-line_3_4__line_25_26_angle_2d_degrees': '0.22975568994654058%'}
frame-22-line_1_2__line_2_3_angle_2d_degrees': '0.2182062381645948%'}
# {'angles_max.frame-22-line_3_4__line_25_26_angle_2d_degrees': '0.21302551225259955%'}
# {'angles_avg.frame-20-line_1_2__line_2_3_angle_2d_degrees': '0.21286303949174662%'}
# {'angles_max.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.21019911892816595%'}
# {'angles_avg.frame-13-line_3_4__line_25_26_angle_2d_degrees': '0.20762317707939926%'}
# {'angles_avg.frame-2-line_1_5__line_5_6_angle_2d_degrees': '0.20592541179079898%'}
# {'angles_avg.frame-25-line_1_5__line_5_6_angle_2d_degrees': '0.19725418306955894%'}
# {'angles_max.frame-25-line_1_5__line_5_6_angle_2d_degrees': '0.19663239433511032%'}
# Mean ROC AUC from cross validation: 0.964
# Min ROC AUC from cross validation: 0.943
# Max ROC AUC from cross validation: 0.988
# Classification Metrics:
# Accuracy: 0.8799
# Precision: 0.8919
# Recall: 0.9747
# F1 Score: 0.9315
# ROC AUC: 0.8321
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.39      0.51        46
#            1       0.89      0.97      0.93       237
#
#     accuracy                           0.88       283
#    macro avg       0.82      0.68      0.72       283
# weighted avg       0.87      0.88      0.86       283

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

# mb.run_pca(num_components=5)
model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# Top 25 features
# {'angles_avg.frame-24-line_1_2__line_2_3_angle_2d_degrees': '0.30698514888619305%'}
# {'angles_avg.frame-23-line_1_2__line_2_3_angle_2d_degrees': '0.289015590415664%'}
# {'angles_avg.frame-13-line_3_4__line_25_26_angle_2d_degrees': '0.24286141608627254%'}
# {'angles_max.frame-21-line_1_2__line_2_3_angle_2d_degrees': '0.2406457610663646%'}
# {'angles_avg.frame-22-line_1_2__line_2_3_angle_2d_degrees': '0.2224398980202238%'}
# {'angles_avg.frame-20-line_1_2__line_2_3_angle_2d_degrees': '0.21910171660394195%'}
# {'angles_avg.frame-3-line_0_15__line_25_26_angle_2d_degrees': '0.2184851778453167%'}
# {'angles_max.frame-25-line_1_2__line_2_3_angle_2d_degrees': '0.21724157141878184%'}
# {'angles_max.frame-5-line_0_15__line_25_26_angle_2d_degrees': '0.21146167566475355%'}
# {'angles_max.frame-22-line_1_2__line_2_3_angle_2d_degrees': '0.2101410152605515%'}
# {'angles_avg.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.209821655229771%'}
# {'angles_avg.frame-25-line_3_4__line_25_26_angle_2d_degrees': '0.2089454868442819%'}
# {'angles_max.frame-12-line_3_4__line_25_26_angle_2d_degrees': '0.2087911593887737%'}
# {'angles_max.frame-20-line_1_2__line_2_3_angle_2d_degrees': '0.2069495307950011%'}
# {'angles_max.frame-24-line_1_2__line_2_3_angle_2d_degrees': '0.20339875882898747%'}
# {'angles_avg.frame-23-line_5_6__line_6_7_angle_2d_degrees': '0.1983681730494581%'}
# {'angles_max.frame-21-line_5_6__line_6_7_angle_2d_degrees': '0.19589489465129564%'}
# {'angles_max.frame-14-line_0_1__line_1_8_angle_2d_degrees': '0.18748406489651853%'}
# {'angles_max.frame-25-line_3_4__line_25_26_angle_2d_degrees': '0.18333563870091507%'}
# {'angles_max.frame-22-line_3_4__line_25_26_angle_2d_degrees': '0.18306068058716768%'}
# {'angles_avg.frame-25-line_1_2__line_2_3_angle_2d_degrees': '0.1811440516683501%'}
# {'angles_max.frame-22-line_5_6__line_6_7_angle_2d_degrees': '0.1727697310886935%'}
# {'angles_avg.frame-5-line_0_15__line_25_26_angle_2d_degrees': '0.17046177929936612%'}
# {'angles_max.frame-13-line_0_15__line_25_26_angle_2d_degrees': '0.16979914304568844%'}
# {'angles_max.frame-17-line_0_15__line_25_26_angle_2d_degrees': '0.16717124663604643%'}
# Mean ROC AUC from cross validation: 0.966
# Min ROC AUC from cross validation: 0.938
# Max ROC AUC from cross validation: 0.991
# Classification Metrics:
# Accuracy: 0.8834
# Precision: 0.9186
# Recall: 0.9518
# F1 Score: 0.9349
# ROC AUC: 0.8206
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.38      0.44        34
#            1       0.92      0.95      0.93       249
#
#     accuracy                           0.88       283
#    macro avg       0.72      0.67      0.69       283
# weighted avg       0.87      0.88      0.88       283

# %% [markdown]
# 82% AUC and 89% accuracy is a decent baseline. I have saved this model.

# %% [markdown]
# ### Test 5 - PCA
#
#
# Next, going to run PCA on this same train / test split and compare. Trying 5 features...

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=5)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806 0.08237575 0.06715103 0.05852736]
# Mean ROC AUC from cross validation: 0.963
# Min ROC AUC from cross validation: 0.932
# Max ROC AUC from cross validation: 0.989
# Classification Metrics:
# Accuracy: 0.8233
# Precision: 0.9198
# Recall: 0.8755
# F1 Score: 0.8971
# ROC AUC: 0.6906
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.44      0.38        34
#            1       0.92      0.88      0.90       249
#
#     accuracy                           0.82       283
#    macro avg       0.62      0.66      0.64       283
# weighted avg       0.85      0.82      0.83       283

# %% [markdown]
# Not quite as good. Will try with a few different component numbers... 2, 11, 25.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=2)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806]
# Mean ROC AUC from cross validation: 0.966
# Min ROC AUC from cross validation: 0.935
# Max ROC AUC from cross validation: 0.987
# Classification Metrics:
# Accuracy: 0.7491
# Precision: 0.8973
# Recall: 0.8072
# F1 Score: 0.8499
# ROC AUC: 0.6129
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.19      0.32      0.24        34
#            1       0.90      0.81      0.85       249
#
#     accuracy                           0.75       283
#    macro avg       0.54      0.57      0.54       283
# weighted avg       0.81      0.75      0.78       283

# %% [markdown]
# Two components, not so good.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=11)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806 0.08237575 0.06715103 0.05852736 0.04541095
#  0.03751028 0.03266918 0.02886933 0.02037861 0.01930305]
# Mean ROC AUC from cross validation: 0.965
# Min ROC AUC from cross validation: 0.927
# Max ROC AUC from cross validation: 0.991
# Classification Metrics:
# Accuracy: 0.8551
# Precision: 0.9160
# Recall: 0.9197
# F1 Score: 0.9178
# ROC AUC: 0.7027
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.39      0.38      0.39        34
#            1       0.92      0.92      0.92       249
#
#     accuracy                           0.86       283
#    macro avg       0.65      0.65      0.65       283
# weighted avg       0.85      0.86      0.85       283

# %% [markdown]
# 11 slightly better but not as good as using raw features.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=25)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806 0.08237575 0.06715103 0.05852736 0.04541095
#  0.03751028 0.03266918 0.02886933 0.02037861 0.01930307 0.01872435
#  0.01562092 0.01495439 0.01488664 0.01401476 0.01241512 0.01194887
#  0.00990014 0.00939903 0.00868459 0.00822363 0.00678515 0.00608804
#  0.00571215]
# Mean ROC AUC from cross validation: 0.962
# Min ROC AUC from cross validation: 0.924
# Max ROC AUC from cross validation: 0.983
# Classification Metrics:
# Accuracy: 0.8763
# Precision: 0.9147
# Recall: 0.9478
# F1 Score: 0.9310
# ROC AUC: 0.7172
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.35      0.41        34
#            1       0.91      0.95      0.93       249
#
#     accuracy                           0.88       283
#    macro avg       0.70      0.65      0.67       283
# weighted avg       0.86      0.88      0.87       283

# %% [markdown]
# Only small improvement. Let's try one more time with 50 components.

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=50)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806 0.08237575 0.06715103 0.05852736 0.04541095
#  0.03751028 0.03266918 0.02886933 0.02037861 0.01930307 0.01872435
#  0.01562092 0.01495439 0.01488664 0.01401476 0.01241512 0.01194887
#  0.00990014 0.00939903 0.0086846  0.00822363 0.00678541 0.00608831
#  0.00571263 0.00504326 0.00495985 0.00471409 0.00465523 0.00437486
#  0.00417368 0.00411399 0.00372651 0.00370592 0.00354478 0.00334679
#  0.00310337 0.00303919 0.00295311 0.0027034  0.00246361 0.00233532
#  0.00221385 0.00211882 0.00207487 0.00190133 0.0018552  0.00182864
#  0.00175467 0.001648  ]
# Mean ROC AUC from cross validation: 0.964
# Min ROC AUC from cross validation: 0.939
# Max ROC AUC from cross validation: 0.987
# Classification Metrics:
# Accuracy: 0.8587
# Precision: 0.8914
# Recall: 0.9558
# F1 Score: 0.9225
# ROC AUC: 0.7297
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.31      0.15      0.20        34
#            1       0.89      0.96      0.92       249
#
#     accuracy                           0.86       283
#    macro avg       0.60      0.55      0.56       283
# weighted avg       0.82      0.86      0.84       283

# %% [markdown]
# 100?

# %%
data_file = "./data/annotated_videos/dataset_1679103956737220000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
model_builder.run_pca(num_components=100)

param_dist = {
    "n_estimators": randint(50, 500),
    "max_depth": randint(1, 20),
    "max_features": randint(3, 20),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params, param_dist=param_dist
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    958
# 0    958
# Name: weight_transfer_type, dtype: int64
# PCA Variance Ratio [0.186029   0.13702806 0.08237575 0.06715103 0.05852736 0.04541095
#  0.03751028 0.03266918 0.02886933 0.02037861 0.01930307 0.01872435
#  0.01562092 0.01495439 0.01488664 0.01401476 0.01241512 0.01194887
#  0.00990014 0.00939903 0.0086846  0.00822363 0.00678541 0.00608831
#  0.00571263 0.00504326 0.00495985 0.00471409 0.00465523 0.00437486
#  0.00417368 0.00411399 0.00372651 0.00370592 0.00354478 0.00334679
#  0.00310337 0.00303919 0.00295311 0.0027034  0.00246361 0.00233532
#  0.00221386 0.00211884 0.00207488 0.00190133 0.00185522 0.00182873
#  0.00175471 0.00164842 0.001645   0.00158274 0.0014718  0.00136878
#  0.00131232 0.00127095 0.00122706 0.00119341 0.00116799 0.00112369
#  0.00106216 0.00099709 0.00093266 0.00090938 0.00086052 0.00085286
#  0.00082326 0.00077393 0.00074101 0.00073206 0.00072068 0.0006714
#  0.00065457 0.00064458 0.0006239  0.00058742 0.00056876 0.00055973
#  0.00055414 0.00053388 0.0005225  0.00050393 0.00049362 0.00047523
#  0.00046456 0.00045091 0.00042742 0.00041272 0.0004083  0.00040665
#  0.00039217 0.00037886 0.00037548 0.00036663 0.0003527  0.00034572
#  0.00033808 0.00032052 0.00031266 0.00030531]
# Mean ROC AUC from cross validation: 0.962
# Min ROC AUC from cross validation: 0.928
# Max ROC AUC from cross validation: 0.990
# Classification Metrics:
# Accuracy: 0.8657
# Precision: 0.8809
# Recall: 0.9799
# F1 Score: 0.9278
# ROC AUC: 0.7332
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.17      0
#  1.28993038e-04 1.24262104e-04 1.21547994e-04 1.19008251e-04
#  1.18009532e-04 1.14543660e-04 1.11573844e-04 1.09028017e-04
#  1.04738417e-04 1.02883862e-04 9.98689488e-05 9.91441697e-05
#  9.53261011e-05 9.44014138e-05 9.18275605e-05 8.86967420e-05
#  8.75363260e-05 8.54886273e-05 8.31039728e-05 8.18640096e-05
#  8.01344762e-05 7.93607689e-05 7.59604888e-05 7.56060380e-05
#  7.24110275e-05 7.14422149e-05 7.00430918e-05 6.93707453e-05
#  6.73292722e-05 6.63248239e-05 6.59208226e-05 6.28293671e-05
#  6.15373045e-05 6.13363367e-05 6.03522411e-05 5.92509955e-05
#  5.78596607e-05 5.70167503e-05 5.62469436e-05 5.35204487e-05
#  5.28148886e-05 5.19677197e-05 5.00141523e-05 4.94894227e-05
#  4.78591950e-05 4.74879751e-05 4.67816270e-05 4.62636798e-05
#  4.58027654e-05 4.36907386e-05 4.22154716e-05 4.21544813e-05
#  4.14148782e-05 4.08348455e-05 3.99041801e-05 3.87942117e-05
#  3.80762150e-05 3.69141546e-05 3.66075515e-05 3.58202874e-05
#  3.53435508e-05 3.37899737e-05 3.35514468e-05 3.28067982e-05
#  3.20627875e-05 3.16172925e-05 3.10268090e-05 2.97823527e-05]
# Mean ROC AUC from cross validation: 0.964
# Min ROC AUC from cross validation: 0.928
# Max ROC AUC from cross validation: 0.993
# Classification Metrics:
# Accuracy: 0.8693
# Precision: 0.8841
# Recall: 0.9799
# F1 Score: 0.9295
# ROC AUC: 0.6165
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.29      0.06      0.10        34
#            1       0.88      0.98      0.93       249
#
#     accuracy                           0.87       283
#    macro avg       0.58      0.52      0.51       283
# weighted avg       0.81      0.87      0.83       283

# %% [markdown]
# So peak seems to be in the 100-200 range, but never higher than without PCA for this train / test split.

# %% [markdown]
# ## Dataset 2
# ### 45 frame Window, pooled averages, standard dev, max over angle measurements

# %% [markdown]
# ### Test 1 - baseline test on Random Forest
#
# Here, upsample the minority class using random sample.

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"
column_whitelist = []

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)

rf_params = {
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0    530
# Name: weight_transfer_type, dtype: int64
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '2.1450539491207254%'}
# {'angles_std.line_3_4__line_25_26_angle_2d_degrees': '2.0828219961360928%'}
# {'angles_avg.line_2_3__line_3_4_angle_2d_degrees': '2.056797360205928%'}
# {'angles_std.line_1_5__line_25_26_angle_2d_degrees': '2.0510370051542557%'}
# {'angles_std.line_1_2__line_2_3_angle_2d_degrees': '2.043192881484721%'}
# Classification Metrics:
# Accuracy: 0.8774
# Precision: 0.8851
# Recall: 0.9850
# F1 Score: 0.9324
# ROC AUC: 0.8390
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.23      0.34        22
#            1       0.89      0.98      0.93       133
#
#     accuracy                           0.88       155
#    macro avg       0.80      0.61      0.64       155
# weighted avg       0.86      0.88      0.85       155

# %% [markdown]
# This is pretty decent - 88% accuracy with 85% ROC AUC - SAVED THIS MODEL

# %% [markdown]
# ### Test 2 - random search over hyperparameters for Random Forest
#
# Here, will randomly choose between these params for a Random Forest 20 times and choose the best one...
#
# ```
# param_dist = {
#     "n_estimators": randint(400, 600),
#     "max_depth": randint(9, 15),
#     "max_features": randint(4, 12),
# }
# ```

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"
column_whitelist = []

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)
# model_builder.run_pca(num_components=200)

param_dist = {
    "n_estimators": randint(400, 600),
    "max_depth": randint(9, 15),
    "max_features": randint(4, 12),
}
rf_params = {
    # "class_weight": "balanced_subsample",
    # "class_weight": "balanced",
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=True, 
    params=rf_params, 
    param_dist=param_dist, 
    iterations=50, 
    random_state = 123
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0    530
# Name: weight_transfer_type, dtype: int64
# Best random search hyperparameters: {'max_depth': 14, 'max_features': 4, 'n_estimators': 475}
# Mean ROC AUC from cross validation: 0.989
# Min ROC AUC from cross validation: 0.953
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_avg.line_2_3__line_3_4_angle_2d_degrees': '1.7700679222213227%'}
# {'angles_std.line_1_5__line_25_26_angle_2d_degrees': '1.6869233504493442%'}
# {'angles_std.line_1_5__line_5_6_angle_2d_degrees': '1.6054378022155091%'}
# {'angles_std.line_1_2__line_2_3_angle_2d_degrees': '1.5782186772139253%'}
# {'angles_avg.line_1_5__line_5_6_angle_2d_degrees': '1.545182336779164%'}
# Classification Metrics:
# Accuracy: 0.8710
# Precision: 0.8693
# Recall: 1.0000
# F1 Score: 0.9301
# ROC AUC: 0.8513
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.09      0.17        22
#            1       0.87      1.00      0.93       133
#
#     accuracy                           0.87       155
#    macro avg       0.93      0.55      0.55       155
# weighted avg       0.89      0.87      0.82       155

# %% [markdown]
# Generally, the results are fairly consistent search to search...

# %% [markdown]
# ### Test 3 - Recursive Feature Elimination on upsampled data
#
# Here, the idea will be to find the best features from the RF classifier and recursively retrain on the best ones. This test will retrain on the top 7 features and then evaluate. Will use the hyperparams found in the previous experiment.
#
# Old
# ```
#     "n_estimators": 600,
#     "max_depth": 9,
#     "max_leaf_nodes": 63,
# ```
#
# New
# ```
#     "n_estimators": 539,
#     "max_depth": 12,
# ```

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)

rf_params = {
    "n_estimators": 475,
    "max_depth": 14,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.run_recursive_feature_estimation(num_features=7)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0    530
# Name: weight_transfer_type, dtype: int64
# Feature Ranks (top 15)
# angles_avg.line_1_5__line_25_26_angle_2d_degrees: 1
# angles_avg.line_1_2__line_2_3_angle_2d_degrees: 1
# angles_avg.line_1_5__line_5_6_angle_2d_degrees: 1
# angles_avg.line_2_3__line_3_4_angle_2d_degrees: 1
# angles_avg.line_5_6__line_6_7_angle_2d_degrees: 1
# angles_std.line_3_4__line_25_26_angle_2d_degrees: 1
# angles_std.line_1_5__line_5_6_angle_2d_degrees: 1
# angles_avg.line_12_13__line_13_14_angle_2d_degrees: 2
# angles_std.line_1_2__line_2_3_angle_2d_degrees: 3
# angles_max.line_3_4__line_25_26_angle_2d_degrees: 4
# angles_avg.line_16_18__line_25_26_angle_2d_degrees: 5
# angles_max.line_5_6__line_6_7_angle_2d_degrees: 6
# angles_std.line_1_5__line_25_26_angle_2d_degrees: 7
# angles_std.line_10_11__line_11_24_angle_2d_degrees: 8
# angles_avg.line_0_15__line_15_17_angle_2d_degrees: 9
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_std.line_3_4__line_25_26_angle_2d_degrees': '2.028214621350669%'}
# {'angles_std.line_1_5__line_5_6_angle_2d_degrees': '2.0193659139998226%'}
# {'angles_std.line_1_5__line_25_26_angle_2d_degrees': '1.93100068078834%'}
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '1.8822407528421756%'}
# {'angles_std.line_1_2__line_2_3_angle_2d_degrees': '1.873605020758948%'}
# Classification Metrics:
# Accuracy: 0.8323
# Precision: 0.8905
# Recall: 0.9173
# F1 Score: 0.9037
# ROC AUC: 0.8407
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.39      0.32      0.35        22
#            1       0.89      0.92      0.90       133
#
#     accuracy                           0.83       155
#    macro avg       0.64      0.62      0.63       155
# weighted avg       0.82      0.83      0.83       155

# %% [markdown]
# Running on both new (from RandSearch) and old (from baseline) features - 76% AUC

# %% [markdown]
# ### Test 4 - RFE on the original imbalanced dataset

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=False,
    upsample_minority=False,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)

rf_params = {
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.run_recursive_feature_estimation(num_features=7)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0     87
# Name: weight_transfer_type, dtype: int64
# Feature Ranks (top 15)
# angles_avg.line_8_12__line_25_26_angle_2d_degrees: 1
# angles_avg.line_0_15__line_25_26_angle_2d_degrees: 1
# angles_avg.line_16_18__line_25_26_angle_2d_degrees: 1
# angles_avg.line_5_6__line_6_7_angle_2d_degrees: 1
# angles_max.line_15_17__line_25_26_angle_2d_degrees: 1
# angles_std.line_1_8__line_25_26_angle_2d_degrees: 1
# angles_std.line_3_4__line_25_26_angle_2d_degrees: 1
# angles_avg.line_9_10__line_25_26_angle_2d_degrees: 2
# angles_std.line_1_5__line_25_26_angle_2d_degrees: 3
# angles_max.line_0_15__line_25_26_angle_2d_degrees: 4
# angles_std.line_1_2__line_25_26_angle_2d_degrees: 5
# angles_max.line_5_6__line_6_7_angle_2d_degrees: 6
# angles_max.line_3_4__line_25_26_angle_2d_degrees: 7
# angles_avg.line_1_5__line_25_26_angle_2d_degrees: 8
# angles_avg.line_3_4__line_25_26_angle_2d_degrees: 9
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_std.line_3_4__line_25_26_angle_2d_degrees': '2.17578713094155%'}
# {'angles_std.line_1_8__line_25_26_angle_2d_degrees': '1.9899356235493704%'}
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '1.9610676849719528%'}
# {'angles_std.line_1_2__line_25_26_angle_2d_degrees': '1.8132259201155725%'}
# {'angles_avg.line_16_18__line_25_26_angle_2d_degrees': '1.688056672513823%'}
# Classification Metrics:
# Accuracy: 0.8774
# Precision: 0.8851
# Recall: 0.9850
# F1 Score: 0.9324
# ROC AUC: 0.7666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.23      0.34        22
#            1       0.89      0.98      0.93       133
#
#     accuracy                           0.88       155
#    macro avg       0.80      0.61      0.64       155
# weighted avg       0.86      0.88      0.85       155

# %% [markdown]
# This is not as good an AUC but overall a decent result given the imbalance. It seems the upsampling is a good idea. I'll constrast this with downsampling.
#
# Top features:
#
# ```
# angles_avg.line_9_10__line_25_26_angle_2d_degrees: 1
# angles_avg.line_0_15__line_25_26_angle_2d_degrees: 1
# angles_avg.line_16_18__line_25_26_angle_2d_degrees: 1
# angles_avg.line_5_6__line_6_7_angle_2d_degrees: 1
# angles_max.line_3_4__line_25_26_angle_2d_degrees: 1
# angles_std.line_1_8__line_25_26_angle_2d_degrees: 1
# angles_std.line_3_4__line_25_26_angle_2d_degrees: 1
# ```
#
# Compare to previous (upsampled) - mostly different. Hmm:
#
# ```
# angles_avg.line_1_5__line_5_6_angle_2d_degrees: 1
# angles_avg.line_2_3__line_3_4_angle_2d_degrees: 1
# angles_avg.line_5_6__line_6_7_angle_2d_degrees: 1
# angles_avg.line_12_13__line_13_14_angle_2d_degrees: 1
# angles_max.line_3_4__line_25_26_angle_2d_degrees: 1
# angles_std.line_3_4__line_25_26_angle_2d_degrees: 1
# angles_std.line_1_5__line_5_6_angle_2d_degrees: 1
# ```

# %% [markdown]
# ### Test 5 - RFE with downsampled majority class

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

model_builder = mb.ModelBuilder()

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=False,
    downsample_majority=True,
    use_SMOTE=False,
    random_state=40002,
)

rf_params = {
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.run_recursive_feature_estimation(num_features=7)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    87
# 0    87
# Name: weight_transfer_type, dtype: int64
# Feature Ranks (top 15)
# weight_transfer_type: 1
# angles_avg.line_8_12__line_25_26_angle_2d_degrees: 1
# angles_avg.line_0_15__line_25_26_angle_2d_degrees: 1
# angles_avg.line_16_18__line_25_26_angle_2d_degrees: 1
# angles_avg.line_5_6__line_6_7_angle_2d_degrees: 1
# angles_max.line_15_17__line_25_26_angle_2d_degrees: 1
# angles_std.line_1_8__line_25_26_angle_2d_degrees: 1
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_avg.line_16_18__line_25_26_angle_2d_degrees': '22.04923686848371%'}
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '18.712847406524595%'}
# {'angles_avg.line_8_12__line_25_26_angle_2d_degrees': '15.475333231817315%'}
# {'angles_avg.line_0_15__line_25_26_angle_2d_degrees': '15.110759024906132%'}
# {'weight_transfer_type': '14.825013416520406%'}
# Classification Metrics:
# Accuracy: 0.7226
# Precision: 0.9167
# Recall: 0.7444
# F1 Score: 0.8216
# ROC AUC: 0.7861
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.28      0.59      0.38        22
#            1       0.92      0.74      0.82       133
#
#     accuracy                           0.72       155
#    macro avg       0.60      0.67      0.60       155
# weighted avg       0.83      0.72      0.76       155

# %% [markdown]
# Much lower accuracy - AUC fairly consistent. I think it's tough with this few samples.

# %% [markdown]
# ### Test 6 - Random Forest with only the top 7 features from RFE, upsampling minority

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

model_builder = mb.ModelBuilder()

column_whitelist = [
    "weight_transfer_type",
    "angles_avg.line_8_12__line_25_26_angle_2d_degrees",
    "angles_avg.line_0_15__line_25_26_angle_2d_degrees",
    "angles_avg.line_16_18__line_25_26_angle_2d_degrees",
    "angles_avg.line_5_6__line_6_7_angle_2d_degrees",
    "angles_max.line_15_17__line_25_26_angle_2d_degrees",
    "angles_std.line_1_8__line_25_26_angle_2d_degrees",
    "angles_std.line_3_4__line_25_26_angle_2d_degrees",
]

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=False,
    random_state=40002,
)

rf_params = {
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0    530
# Name: weight_transfer_type, dtype: int64
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_avg.line_16_18__line_25_26_angle_2d_degrees': '22.783550002783105%'}
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '17.08866042702732%'}
# {'angles_avg.line_8_12__line_25_26_angle_2d_degrees': '16.743172768040044%'}
# {'weight_transfer_type': '15.849256823555299%'}
# {'angles_avg.line_0_15__line_25_26_angle_2d_degrees': '14.034402977034402%'}
# Classification Metrics:
# Accuracy: 0.8387
# Precision: 0.8913
# Recall: 0.9248
# F1 Score: 0.9077
# ROC AUC: 0.7878
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.32      0.36        22
#            1       0.89      0.92      0.91       133
#
#     accuracy                           0.84       155
#    macro avg       0.65      0.62      0.63       155
# weighted avg       0.82      0.84      0.83       155

# %% [markdown]
# ROC AUC - 78%, accuracy 84%

# %% [markdown]
# ## Test 7 - Random Forest on Upsampled Data Using SMOTE - top 7 RFE features

# %%
data_file = "./data/annotated_videos/dataset_1679015606654767000.csv"

model_builder = mb.ModelBuilder()

column_whitelist = [
    "weight_transfer_type",
    "angles_avg.line_8_12__line_25_26_angle_2d_degrees",
    "angles_avg.line_0_15__line_25_26_angle_2d_degrees",
    "angles_avg.line_16_18__line_25_26_angle_2d_degrees",
    "angles_avg.line_5_6__line_6_7_angle_2d_degrees",
    "angles_max.line_15_17__line_25_26_angle_2d_degrees",
    "angles_std.line_1_8__line_25_26_angle_2d_degrees",
    "angles_std.line_3_4__line_25_26_angle_2d_degrees",
]

model_builder.load_and_prep_dataset_from_csv(
    path=data_file,
    target="weight_transfer_type",
    value_map=value_map,
    column_whitelist=column_whitelist,
    drop_list=drop_list,
)

model_builder.set_train_test_split(
    balance_off_target=True,
    upsample_minority=True,
    downsample_majority=False,
    use_SMOTE=True,
    random_state=40002,
)

rf_params = {
    "n_estimators": 600,
    "max_depth": 9,
    "max_leaf_nodes": 63,
}

model_builder.train_random_forest(
    use_random_search=False, params=rf_params
)
model_builder.evaluate_model()
# Out:
# Training Balance for weight_transfer_type:
# 1    530
# 0    530
# Name: weight_transfer_type, dtype: int64
# /Users/nathanielgreen/Dev-Local/stream_pose_ml/stream_pose_ml/stream_pose_ml/learning/model_builder.py:331: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Mean ROC AUC from cross validation: 1.000
# Min ROC AUC from cross validation: 1.000
# Max ROC AUC from cross validation: 1.000
# Top 5 features
# {'angles_avg.line_16_18__line_25_26_angle_2d_degrees': '24.214798141836514%'}
# {'angles_avg.line_5_6__line_6_7_angle_2d_degrees': '19.533002528835137%'}
# {'angles_std.line_1_8__line_25_26_angle_2d_degrees': '15.671395343066024%'}
# {'angles_avg.line_8_12__line_25_26_angle_2d_degrees': '14.207319609344344%'}
# {'angles_avg.line_0_15__line_25_26_angle_2d_degrees': '13.426962734249487%'}
# Classification Metrics:
# Accuracy: 0.8065
# Precision: 0.9120
# Recall: 0.8571
# F1 Score: 0.8837
# ROC AUC: 0.7522
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.50      0.42        22
#            1       0.91      0.86      0.88       133
#
#     accuracy                           0.81       155
#    macro avg       0.64      0.68      0.65       155
# weighted avg       0.83      0.81      0.82       155

# %% [markdown]
# 75% ROC AUC and 81% accuracy

# %% [markdown]
# # Save current model and related data to files

# %%
""" WRITE NOTES ON THIS RUN HERE """
notes = """
    Dataset notes:
    45 frame window with pooled angle features (avg / std / max)
    This training data upsamples the minority class by random sample.

    Model notes:
    Random Forest classifier trained with
        "n_estimators": 600,
        "max_depth": 9,
        "max_leaf_nodes": 63,
    """

model_builder.save_model_and_datasets(notes=notes)
# Out:
# Saved model to pickle!
