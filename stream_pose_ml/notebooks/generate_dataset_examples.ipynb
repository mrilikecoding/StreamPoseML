# %% [markdown]
# # Build Datasets

# %% [markdown]
# ### Handle imports

# %%
import sys
import os
import time

# Assuming the notebook is in the "notebooks" folder, we go one level up to include the "stream_pose_ml" package.
parent_directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

if parent_directory not in sys.path:
    sys.path.append(parent_directory)

import stream_pose_ml.jobs.process_videos_job as pv
import stream_pose_ml.jobs.build_and_format_dataset_job as data_builder

# %% [markdown]
# ### I/O File Locations
#
# Relative to this directory ./stream_pose_ml/notebooks

# %%
# The location of video files
source_videos_directory = "../../data/source_videos"

# The location of Dataloop Annotations corresponding to each video
source_annotations_directory = "../../data/source_annotations"

# The location to output sequence data
sequence_data_directory = "../../data/sequences"

# The location to output keypoint data
keypoints_data_directory = "../../data/keypoints"

# The location to output datasets
merged_annotation_output_directory = "../../data/annotated_videos"

# %% [markdown]
# ### Generate Keypoint and Sequence Data

# %%
# give a timestamped folder to not overwrite
# folder = f"run-preproccessed-{time.time_ns()}"  
folder = "run-preproccessed-1697924524790004000"
keypoints_path = f"{keypoints_data_directory}/{folder}"
sequence_path = f"{sequence_data_directory}/{folder}"

# %%
pv.ProcessVideosJob().process_videos(
    src_videos_path=source_videos_directory,
    output_keypoints_data_path=keypoints_path,
    output_sequence_data_path=sequence_path,
    write_keypoints_to_file=True,
    write_serialized_sequence_to_file=True,
    limit=None,
    configuration={},
    preprocess_video=True,
    return_output=False
)
# Out:
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front_P5.webm_sequence.json.
# 1/86 completed: IKF_8.27_1230pm_BW_Front_P5.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front_P4.webm_sequence.json.
# 2/86 completed: IKF_8.27_11am_BW_Front_P4.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_2pm_BW_Front_P63.webm_sequence.json.
# 3/86 completed: IRC_9.11_2pm_BW_Front_P63.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front_P26.webm_sequence.json.
# 4/86 completed: IKF_8.31_1030am_BW_Front_P26.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_12pm_BW_Front_P30.webm_sequence.json.
# 5/86 completed: IKF_8.31_12pm_BW_Front_P30.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front_P47.webm_sequence.json.
# 6/86 completed: IKF_9.3_230pm_BW_Front_P47.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_11am_BW_Front2_P58.webm_sequence.json.
# 7/86 completed: IRC_9.11_11am_BW_Front2_P58.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front2_P2.webm_sequence.json.
# 8/86 completed: IKF_8.27_11am_BW_Front2_P2.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front2_P43.webm_sequence.json.
# 9/86 completed: WLR_9.1.1pm_BW_Front2_P43.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front2_P27.webm_sequence.json.
# 10/86 completed: IKF_8.31_1030am_BW_Front2_P27.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front2_P26.webm_sequence.json.
# 11/86 completed: IKF_8.31_1030am_BW_Front2_P26.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front2_P42.webm_sequence.json.
# 12/86 completed: WLR_9.1.1pm_BW_Front2_P42.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front2_P3.webm_sequence.json.
# 13/86 completed: IKF_8.27_11am_BW_Front2_P3.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front_P8.webm_sequence.json.
# 14/86 completed: IKF_8.27_1230pm_BW_Front_P8.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_12pm_BW_Front_P31.webm_sequence.json.
# 15/86 completed: IKF_8.31_12pm_BW_Front_P31.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_12pm_BW_Front2_P31.webm_sequence.json.
# 16/86 completed: IKF_8.31_12pm_BW_Front2_P31.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front_P27.webm_sequence.json.
# 17/86 completed: IKF_8.31_1030am_BW_Front_P27.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front_P41.webm_sequence.json.
# 18/86 completed: WLR_9.1.1pm_BW_Front_P41.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_2pm_BW_Front_P62.webm_sequence.json.
# 19/86 completed: IRC_9.11_2pm_BW_Front_P62.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1130am_BW_Front2_P40.webm_sequence.json.
# 20/86 completed: WLR_9.8_1130am_BW_Front2_P40.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front2_P50.webm_sequence.json.
# 21/86 completed: WLR_9.8_10am_BW_Front2_P50.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1130am_BW_Front_P53.webm_sequence.json.
# 22/86 completed: WLR_9.8_1130am_BW_Front_P53.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front_P50.webm_sequence.json.
# 23/86 completed: WLR_9.8_10am_BW_Front_P50.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front2_P9.webm_sequence.json.
# 24/86 completed: IKF_8.27_230pm_BW_Front2_P9.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_8.28_130pm_BW_Front_P18.webm_sequence.json.
# 25/86 completed: IRC_8.28_130pm_BW_Front_P18.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front2_P4.webm_sequence.json.
# 26/86 completed: IKF_8.27_11am_BW_Front2_P4.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_1230pm_BW_Front2_P60.webm_sequence.json.
# 27/86 completed: IRC_9.11_1230pm_BW_Front2_P60.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.10_10am_BW_Front_P56.webm_sequence.json.
# 28/86 completed: IKF_9.10_10am_BW_Front_P56.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_1230pm_BW_Front3_P60.webm_sequence.json.
# 29/86 completed: IRC_9.11_1230pm_BW_Front3_P60.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front2_P49.webm_sequence.json.
# 30/86 completed: IKF_9.3_230pm_BW_Front2_P49.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_11am_BW_Front_P57.webm_sequence.json.
# 31/86 completed: IRC_9.11_11am_BW_Front_P57.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front_P9.webm_sequence.json.
# 32/86 completed: IKF_8.27_230pm_BW_Front_P9.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front_P2.webm_sequence.json.
# 33/86 completed: IKF_8.27_11am_BW_Front_P2.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front2_P6.webm_sequence.json.
# 34/86 completed: IKF_8.27_1230pm_BW_Front2_P6.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_1230pm_BW_Front_P61.webm_sequence.json.
# 35/86 completed: IRC_9.11_1230pm_BW_Front_P61.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_1230pm_BW_Front_P60.webm_sequence.json.
# 36/86 completed: IRC_9.11_1230pm_BW_Front_P60.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1_230pm_BW_Front2_P44.webm_sequence.json.
# 37/86 completed: WLR_9.1_230pm_BW_Front2_P44.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1pm_BW_Front2_P55.webm_sequence.json.
# 38/86 completed: WLR_9.8_1pm_BW_Front2_P55.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front_P3.webm_sequence.json.
# 39/86 completed: IKF_8.27_11am_BW_Front_P3.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front2_P48.webm_sequence.json.
# 40/86 completed: IKF_9.3_230pm_BW_Front2_P48.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_1230pm_BW_Front2_P61.webm_sequence.json.
# 41/86 completed: IRC_9.11_1230pm_BW_Front2_P61.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front3_P9.webm_sequence.json.
# 42/86 completed: IKF_8.27_230pm_BW_Front3_P9.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front_P51.webm_sequence.json.
# 43/86 completed: WLR_9.8_10am_BW_Front_P51.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front2_P51.webm_sequence.json.
# 44/86 completed: WLR_9.8_10am_BW_Front2_P51.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.03_1130am_BW_Front2_P46.webm_sequence.json.
# 45/86 completed: IKF_9.03_1130am_BW_Front2_P46.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.03_1130am_BW_Front_P45.webm_sequence.json.
# 46/86 completed: IKF_9.03_1130am_BW_Front_P45.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front2_P8.webm_sequence.json.
# 47/86 completed: IKF_8.27_1230pm_BW_Front2_P8.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front_P52.webm_sequence.json.
# 48/86 completed: WLR_9.8_10am_BW_Front_P52.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front2_P52.webm_sequence.json.
# 49/86 completed: WLR_9.8_10am_BW_Front2_P52.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front3_P52.webm_sequence.json.
# 50/86 completed: WLR_9.8_10am_BW_Front3_P52.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.03_1130am_BW_Front2_P45.webm_sequence.json.
# 51/86 completed: IKF_9.03_1130am_BW_Front2_P45.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.03_1130am_BW_Front_P46.webm_sequence.json.
# 52/86 completed: IKF_9.03_1130am_BW_Front_P46.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front2_P47.webm_sequence.json.
# 53/86 completed: IKF_9.3_230pm_BW_Front2_P47.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_8.28_130pm_BW_Front2_P18.webm_sequence.json.
# 54/86 completed: IRC_8.28_130pm_BW_Front2_P18.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front_P10.webm_sequence.json.
# 55/86 completed: IKF_8.27_230pm_BW_Front_P10.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front3_P5.webm_sequence.json.
# 56/86 completed: IKF_8.27_1230pm_BW_Front3_P5.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1130am_BW_Front3_P53.webm_sequence.json.
# 57/86 completed: WLR_9.8_1130am_BW_Front3_P53.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1130am_BW_Front2_P53.webm_sequence.json.
# 58/86 completed: WLR_9.8_1130am_BW_Front2_P53.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front_P11.webm_sequence.json.
# 59/86 completed: IKF_8.27_230pm_BW_Front_P11.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front_P1.webm_sequence.json.
# 60/86 completed: IKF_8.27_11am_BW_Front_P1.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front2_P5.webm_sequence.json.
# 61/86 completed: IKF_8.27_1230pm_BW_Front2_P5.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_11am_BW_Front_P58.webm_sequence.json.
# 62/86 completed: IRC_9.11_11am_BW_Front_P58.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1pm_BW_Front_P55.webm_sequence.json.
# 63/86 completed: WLR_9.8_1pm_BW_Front_P55.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.10_10am_BW_Front2_P56.webm_sequence.json.
# 64/86 completed: IKF_9.10_10am_BW_Front2_P56.webm.
# [matroska,webm @ 0x56d484400] File ended prematurely
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front_P42.webm_sequence.json.
# 65/86 completed: WLR_9.1.1pm_BW_Front_P42.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front2_P10.webm_sequence.json.
# 66/86 completed: IKF_8.27_230pm_BW_Front2_P10.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front_P49.webm_sequence.json.
# 67/86 completed: IKF_9.3_230pm_BW_Front_P49.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front3_P1.webm_sequence.json.
# 68/86 completed: IKF_8.27_11am_BW_Front3_P1.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front_P28.webm_sequence.json.
# 69/86 completed: IKF_8.31_1030am_BW_Front_P28.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_2pm_BW_Front2_P62.webm_sequence.json.
# 70/86 completed: IRC_9.11_2pm_BW_Front2_P62.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front2_P41.webm_sequence.json.
# 71/86 completed: WLR_9.1.1pm_BW_Front2_P41.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front5_P9.webm_sequence.json.
# 72/86 completed: IKF_8.27_230pm_BW_Front5_P9.webm.
# [matroska,webm @ 0x5b3551600] File ended prematurely at pos. 524288 (0x80000)
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_10am_BW_Front_P54.webm_sequence.json.
# 73/86 completed: WLR_9.8_10am_BW_Front_P54.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1_230pm_BW_Front_P44.webm_sequence.json.
# 74/86 completed: WLR_9.1_230pm_BW_Front_P44.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.8_1130am_BW_Front_P40.webm_sequence.json.
# 75/86 completed: WLR_9.8_1130am_BW_Front_P40.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_11am_BW_Front2_P1.webm_sequence.json.
# 76/86 completed: IKF_8.27_11am_BW_Front2_P1.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_2pm_BW_Front2_P63.webm_sequence.json.
# 77/86 completed: IRC_9.11_2pm_BW_Front2_P63.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front4_P9.webm_sequence.json.
# 78/86 completed: IKF_8.27_230pm_BW_Front4_P9.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IRC_9.11_11am_BW_Front2_P57.webm_sequence.json.
# 79/86 completed: IRC_9.11_11am_BW_Front2_P57.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_230pm_BW_Front2_P11.webm_sequence.json.
# 80/86 completed: IKF_8.27_230pm_BW_Front2_P11.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_9.3_230pm_BW_Front_P48.webm_sequence.json.
# 81/86 completed: IKF_9.3_230pm_BW_Front_P48.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.27_1230pm_BW_Front_P6.webm_sequence.json.
# 82/86 completed: IKF_8.27_1230pm_BW_Front_P6.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_12pm_BW_Front_P29.webm_sequence.json.
# 83/86 completed: IKF_8.31_12pm_BW_Front_P29.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_12pm_BW_Front2_P29.webm_sequence.json.
# 84/86 completed: IKF_8.31_12pm_BW_Front2_P29.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/IKF_8.31_1030am_BW_Front2_P28.webm_sequence.json.
# 85/86 completed: IKF_8.31_1030am_BW_Front2_P28.webm.
# Successfully wrote ../../data/sequences/run-preproccessed-1697924524790004000/WLR_9.1.1pm_BW_Front_P43.webm_sequence.json.
# 86/86 completed: WLR_9.1.1pm_BW_Front_P43.webm.
# {'keypoints_path': '../../data/keypoints/run-preproccessed-1697924524790004000',
#  'sequence_path': '../../data/sequences/run-preproccessed-1697924524790004000'}

# %% [markdown]
# # Datasets from Keypoints + Sequence Data

# %% [markdown]
# ### Generate Dataset
#
# TODO enumerate all the options here...
#
#
# #### Labels
# ```
# step_type
# weight_transfer_type
# ```
# #### Segmentation Strategy
# ```
# flatten_into_columns
# flatten_on_example
# split_on_label
# window
# none
# ```

# %% [markdown]
# ### Split on Step Type, pooled temporal dynamics with angles and distances

# %%
# Specify the location of the sequence data you ran above (the sequence folder path)
sequence_data_directory = sequence_path

db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=True,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="split_on_label",
    segmentation_splitter_label="step_type",
    segmentation_window=None,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="pooled_angles_distances_full_examples"
)
# Out:
# KeyError for key: nose_neck_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: right_shoulder_right_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: right_elbow_right_wrist_to_plumb_line.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: right_hip_right_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_right_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: right_eye_right_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_left_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: left_eye_left_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_neck_mid_hip.angle_2d_degrees
# KeyError for key: nose_neck_to_neck_right_shoulder.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_mid_hip_left_hip.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_right_shoulder_right_elbow.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_left_shoulder_left_elbow.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_right_elbow_right_wrist.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_right_hip_right_knee.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_right_ankle_right_heel.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_left_hip_left_knee.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_left_knee_left_ankle.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_left_ankle_left_foot_index.angle_2d_degrees
# KeyError for key: nose_right_eye_to_right_eye_right_ear.angle_2d_degrees
# KeyError for key: nose_left_eye_to_left_eye_left_ear.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_right_ankle_right_foot_index.angle_2d_degrees
# KeyError for key: nose_neck_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: right_shoulder_right_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: right_elbow_right_wrist_to_plumb_line.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: right_hip_right_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_right_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: right_eye_right_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_left_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: left_eye_left_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_neck_mid_hip.angle_2d_degrees
# KeyError for key: nose_neck_to_neck_right_shoulder.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_mid_hip_left_hip.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_right_shoulder_right_elbow.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_left_shoulder_left_elbow.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_right_elbow_right_wrist.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_right_hip_right_knee.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_right_ankle_right_heel.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_left_hip_left_knee.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_left_knee_left_ankle.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_left_ankle_left_foot_index.angle_2d_degrees
# KeyError for key: nose_right_eye_to_right_eye_right_ear.angle_2d_degrees
# KeyError for key: nose_left_eye_to_left_eye_left_ear.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_right_ankle_right_foot_index.angle_2d_degrees
# KeyError for key: nose_neck_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: right_shoulder_right_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: right_elbow_right_wrist_to_plumb_line.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: right_hip_right_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_right_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: right_eye_right_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_left_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: left_eye_left_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_neck_mid_hip.angle_2d_degrees
# KeyError for key: nose_neck_to_neck_right_shoulder.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_mid_hip_left_hip.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_right_shoulder_right_elbow.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_left_shoulder_left_elbow.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_right_elbow_right_wrist.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_right_hip_right_knee.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_right_ankle_right_heel.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_left_hip_left_knee.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_left_knee_left_ankle.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_left_ankle_left_foot_index.angle_2d_degrees
# KeyError for key: nose_right_eye_to_right_eye_right_ear.angle_2d_degrees
# KeyError for key: nose_left_eye_to_left_eye_left_ear.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_right_ankle_right_foot_index.angle_2d_degrees
# KeyError for key: nose_neck_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_plumb_line.angle_2d_degrees
# KeyError for key: right_shoulder_right_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: right_elbow_right_wrist_to_plumb_line.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: right_hip_right_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_plumb_line.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_plumb_line.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_right_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: right_eye_right_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: nose_left_eye_to_plumb_line.angle_2d_degrees
# KeyError for key: left_eye_left_ear_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_foot_index_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_plumb_line.angle_2d_degrees
# KeyError for key: right_ankle_right_heel_to_neck_mid_hip.angle_2d_degrees
# KeyError for key: nose_neck_to_neck_right_shoulder.angle_2d_degrees
# KeyError for key: neck_mid_hip_to_mid_hip_left_hip.angle_2d_degrees
# KeyError for key: neck_right_shoulder_to_right_shoulder_right_elbow.angle_2d_degrees
# KeyError for key: neck_left_shoulder_to_left_shoulder_left_elbow.angle_2d_degrees
# KeyError for key: left_shoulder_left_elbow_to_right_elbow_right_wrist.angle_2d_degrees
# KeyError for key: mid_hip_right_hip_to_right_hip_right_knee.angle_2d_degrees
# KeyError for key: right_knee_right_ankle_to_right_ankle_right_heel.angle_2d_degrees
# KeyError for key: mid_hip_left_hip_to_left_hip_left_knee.angle_2d_degrees
# KeyError for key: left_hip_left_knee_to_left_knee_left_ankle.angle_2d_degrees
# KeyError for key: left_knee_left_ankle_to_left_ankle_left_foot_index.angle_2d_degrees
# KeyError for key: nose_right_eye_to_right_eye_right_ear.angle_2d_degrees
# KeyError for key: nose_left_eye_to_left_eye_left_ear.angle_2d_degrees
# KeyError for key: left_ankle_left_heel_to_right_ankle_right_foot_index.angle_2d_degrees
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb Cell 12 line 1
#       <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> db = data_builder.BuildAndFormatDatasetJob()
#       <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> dataset = db.build_dataset_from_data_files(
#       <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     annotations_data_directory=source_annotations_directory,
#       <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>     sequence_data_directory=sequence_data_directory,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>     limit=None,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> )
# ---> <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> formatted_dataset = db.format_dataset(
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>     dataset=dataset,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>     pool_frame_data_by_clip=True,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a>     decimal_precision=4,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a>     include_unlabeled_data=True,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a>     include_angles=True,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a>     include_distances=True,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a>     include_normalized=True,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a>     segmentation_strategy="split_on_label",
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>     segmentation_splitter_label="step_type",
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a>     segmentation_window=None,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a>     segmentation_window_label="weight_transfer_type",
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a> )
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> db.write_dataset_to_csv(
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=27'>28</a>     csv_location=merged_annotation_output_directory,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=28'>29</a>     formatted_dataset=formatted_dataset,
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=29'>30</a>     filename="pooled_angles_distances_full_examples"
#      <a href='vscode-notebook-cell:/Users/nathangreen/Development/StreamPoseML/stream_pose_ml/notebooks/generate_dataset.ipynb#X13sZmlsZQ%3D%3D?line=30'>31</a> )
#
# File ~/Development/StreamPoseML/stream_pose_ml/stream_pose_ml/jobs/build_and_format_dataset_job.py:133, in BuildAndFormatDatasetJob.format_dataset(dataset, pool_frame_data_by_clip, decimal_precision, include_unlabeled_data, include_angles, include_distances, include_normalized, include_joints, include_z_axis, segmentation_strategy, segmentation_splitter_label, segmentation_window, segmentation_window_label)
#     124 segmented_dataset = segmentation_service.segment_dataset(dataset)
#     125 dataset_serializer = DatasetSerializer(
#     126     pool_rows=pool_frame_data_by_clip,
#     127     include_normalized=include_normalized,
#    (...)
#     131     include_z_axis=include_z_axis,
#     132 )
# --> 133 formatted_data = dataset_serializer.serialize(segmented_dataset)
#     135 if decimal_precision is not None:
#     136     rounded = []
#
# File ~/Development/StreamPoseML/stream_pose_ml/stream_pose_ml/serializers/dataset_serializer.py:70, in DatasetSerializer.serialize(self, dataset)
#      66 for clip in segmented_dataset:
#      67     if self.pool_rows:
#      68         # append pooled frame data to rows
#      69         rows.append(
# ---> 70             clip_serializer.serialize(labeled_clip=clip, pool_rows=True)
#      71         )
#      72     else:
#      73         # append list of frame data to rows
#      74         clip_data = clip_serializer.serialize(
#      75             labeled_clip=clip, pool_rows=False
#      76         )
#
# File ~/Development/StreamPoseML/stream_pose_ml/stream_pose_ml/serializers/labeled_clip_serializer.py:94, in LabeledClipSerializer.serialize(self, labeled_clip, pool_rows)
#      92         clip_data["angles_max"] = tfp.compute_max(angles)
#      93     if self.pool_std:
# ---> 94         clip_data["angles_std"] = tfp.compute_standard_deviation(angles)
#      95 if self.include_distances:
#      96     distances = [frame["distances"] for frame in frame_rows]
#
# File ~/Development/StreamPoseML/stream_pose_ml/stream_pose_ml/learning/temporal_feature_pooling.py:21, in compute_standard_deviation(dict_list)
#      19 std_dict = {}
#      20 for key in dict_list[0].keys():
# ---> 21     mean = sum(d[key] for d in dict_list) / len(dict_list)
#      22     std_dict[key] = sum((d[key] - mean) ** 2 for d in dict_list) / len(dict_list)
#      24 return std_dict
#
# File ~/Development/StreamPoseML/stream_pose_ml/stream_pose_ml/learning/temporal_feature_pooling.py:21, in <genexpr>(.0)
#      19 std_dict = {}
#      20 for key in dict_list[0].keys():
# ---> 21     mean = sum(d[key] for d in dict_list) / len(dict_list)
#      22     std_dict[key] = sum((d[key] - mean) ** 2 for d in dict_list) / len(dict_list)
#      24 return std_dict
#
# KeyError: 'nose_neck_to_plumb_line.angle_2d_degrees'

# %% [markdown]
# ### Split on Step Type, pooled temporal dynamics with angles and distances, only the last 10 frames

# %%
# sequence generated on 3/24/23 with new normalized values
sequence_data_directory= "../../data/sequences/run-1679706020787139000"

db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=True,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="split_on_label",
    segmentation_splitter_label="step_type",
    segmentation_window=10,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="pooled_angles_distances_last_10_frames"
)

# %% [markdown]
# ### Flatten columns over 10 frame window on step type (arbitrary start / end)

# %%
# sequence generated on 3/24/23 with new normalized values
sequence_data_directory= "../../data/sequences/run-1679706020787139000"

db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=True,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="split_on_label",
    segmentation_splitter_label="step_type",
    segmentation_window=10,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="pooled_angles_distances_last_10_frames"
)

# %% [markdown]
# ### Flatten on a 10 frame window based on complete training examples (the end of the example will flatten the previous 10 frames into a training row0)

# %%
# sequence generated on 3/24/23 with new normalized values
sequence_data_directory= "../../data/sequences/run-1679706020787139000"

db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=False,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="flatten_on_example",
    segmentation_splitter_label="step_type",
    segmentation_window=10,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="flatten_on_example_10_frames_2"
)
# Out:
# True

# %% [markdown]
# ### Flatten on a 25 frame window based on complete training examples (the end of the example will flatten the previous 25 frames into a training row)

# %%
# sequence generated on 3/24/23 with new normalized values
# sequence_data_directory= "../../data/sequences/run-1679706020787139000"
sequence_data_directory = "../../data/sequences/run-preproccessed-1680117203184086000"


db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=False,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="flatten_on_example",
    segmentation_splitter_label="step_type",
    segmentation_window=25,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="preprocessed_flatten_on_example_25_frames_2"
)

# %% [markdown]
# ### Dataset with all frames as rows

# %%
sequence_data_directory = "../../data/sequences/run-preproccessed-1680117203184086000"
db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=False,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=True,
    include_distances=True,
    include_normalized=True,
    segmentation_strategy="none",
    segmentation_splitter_label="step_type",
    segmentation_window=25,
    segmentation_window_label="weight_transfer_type",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="preprocessed_all_rows-5-9-23.csv",
    pool_frame_data_by_clip=False,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_angles=False,
    include_distances=False,
    include_normalized=False,
    segmentation_strategy="none",
)

# %% [markdown]
# ### Dataset with raw x, y, z joint data, with one frame per row

# %%
sequence_data_directory = "../../data/sequences/run-preproccessed-1680117203184086000"
db = data_builder.BuildAndFormatDatasetJob()
dataset = db.build_dataset_from_data_files(
    annotations_data_directory=source_annotations_directory,
    sequence_data_directory=sequence_data_directory,
    limit=None,
)

formatted_dataset = db.format_dataset(
    dataset=dataset,
    pool_frame_data_by_clip=False,
    decimal_precision=4,
    include_unlabeled_data=True,
    include_joints=True,
    include_z_axis=True,
    include_angles=False,
    include_distances=False,
    include_normalized=False,
    segmentation_strategy="none",
)

db.write_dataset_to_csv(
    csv_location=merged_annotation_output_directory,
    formatted_dataset=formatted_dataset,
    filename="preprocessed_frame_joint_data-6-19-23"
)
# Out:
# True
